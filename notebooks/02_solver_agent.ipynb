# %% [markdown]
# # Solver Agent
#
# Basic solver experiments with SymPy-backed logic.

# %%
from src.agents.interpreter import InterpreterAgent
from src.agents.solver import SolverAgent
task = InterpreterAgent().run("x**2 - 5*x + 6 = 0")
SolverAgent().run(task)
